# %% [markdown]
# <p><img alt="banner" height="252px" width="1080px" src="https://docs.google.com/uc?export=download&id=1YJrz-tzQUkofEE37sRUdlCbnXf10gJlF"  align="center" hspace="10px" vspace="0px"></p>

# %% [markdown]
# # <font color='056938'> **Introducción a la programación - </font> <font color='8EC044'> Variables y operadores** </font>

# %% [markdown]
# Consideremos el siguiente juego:
#
# > Escoges un número aleatorio entre 1 y 10 y el computador genera también un número aleatorio en el mismo rango. El **GANADOR** será quien obtenga el número mayor.
#
# Para determinar el ganador debemos estar en capacidad de comparar el número dado por nosotros con el número que genera el computador y para poder comparar los números debemos estar en capacidad de guardar el número generado.
#
# En situaciones como estas usamos `variables`.

# %% [markdown]
# # <font color='056938'> **Variables** </font>
#
# Una *Variable* puede ser entendida como un contenedor de datos, en términos de computación es un espacio reservado en la memoria del computador para almacenar un dato que puede ser usado o modificado tantas veces como se desee. El buen uso de la variables parte del uso de nombres apropiados
#
# * Tener un nombre que sea fácilmente interpretable en el código
# * No tener el mismo nombre que una “palabra reservada” del lenguaje. <a href="https://es.wikibooks.org/wiki/Python/Generalidades/Palabras_reservadas,_operadores_y_s%C3%ADmbolos_del_lenguaje">Palabras reservadas en Python</a>
# * Sólo pueden ser letras, dígitos y el guion bajo o subguion.
# * Deben comenzar por una carácter (letra).
# * No puede incluir espacios en blanco.
# * No pueden llevar acento (tilde)
#
#
# Consideremos el ejemplo del juego con el que iniciamos la sección. Corre el siguiente código hasta que ganes:

# %%
import random # importa la libreria random

nombre = input("¿Cuál es su nombre?:    ") # Obtener el nombre del usuario
aleatorio = random.randint(1, 10) # Genera un número aletaorio entero entre 1 y 10
jugador = int(input("Ingrese un número entero entre 1 y 10: ")) # Pregunta un número al usuario

print(f'\nPC generó el número número: {aleatorio}')
print(f'{nombre}, ingresaste el número: {jugador}')

print(f'\n{nombre} ganaste! 🙂' if jugador>aleatorio else '{nombre} perdiste! 🙁') # Más adelante conoceras en detalle como funciona la instrucción if y else
# Out:
# ¿Cuál es su nombre?:    Felipe
# Ingrese un número entero entre 1 y 10: 5
#
# PC generó el número número: 6
# Felipe, ingresaste el número: 5
# {nombre} perdiste! 🙁

# %% [markdown]
# ### <font color='46B8A9'> **Ejercicio 1:** </font>
# ¿Qué variables se usan en el ejemplo?

# %% [markdown]
# ## <font color='157699'> **Tipos de datos** </font>
#
# Los datos almacenados en una variable pueden ser de diversos tipos. El tipo de datos es el atributo que especifica al computador la clase de dato que tiene que manejar, para saber qué valores puede tomar y qué operaciones realizar. Algunos de los tipos de datos básicos (usualmente llamados tipos primitivos o elementales) son:
#
# * Números enteros: ...-3, -2, -1, 0, 1, 2, 3, ...
# * Números en coma flotante (decimales). Dependiendo del lenguaje podrían recibir distintos nombres o clasificarse de distintas maneras como *double* o *float*
# * Caracteres (alfanuméricos) - `char`
# * Cadenas de caracteres (textos) - `str`
# * Estados lógicos (booleanos) - `int`
#
# Note que existen una gran cantidad de tipos de datos y que incluso la disponibilidad de estos pueden cambiar dependiendo del lenguaje.
#
# Veamos un ejemplo de cada uno de ellos:

# %%
entero = 4 # variable entera
print("Una variable entera: ", entero)
decimal = -1.3 # variable real
print("Una variable real: ", decimal)
caracter = "a" # variable caracter
print("Una variable caracter: ", caracter)
cadena = "Pablo" # variable cadena
print("Una variable string: ", cadena)
estadoLogico = False # variable booleano
print("Una variable de estado lógico: ", estadoLogico)
# Out:
# Una variable entera:  4
# Una variable real:  -1.3
# Una variable caracter:  a
# Una variable string:  Pablo
# Una variable de estado lógico:  False

# %% [markdown]
# ### <font color='46B8A9'> **Ejercicio 2:** </font>
# ¿Qué tipos de datos almacenan variables en el siguiente ejemplo?

# %%
import random # importa la libreria random

nombre = input("¿Cuál es su nombre?:    ") # Obtener el nombre del usuario
aleatorio = random.randint(1, 10) # Genera un número aletaorio entero entre 1 y 10
jugador = int(input("Ingrese un número entero entre 1 y 10: ")) # Pregunta un número al usuario

print(f'\nPC generó el número número: {aleatorio}')
print(f'{nombre}, ingresaste el número: {jugador}')

print(f'\n{nombre} ganaste! 🙂' if jugador>aleatorio else '{nombre} perdiste! 🙁') # Más adelante conoceras en detalle como funciona la instrucción if y else
# Out:
# ¿Cuál es su nombre?:    Felipe
# Ingrese un número entero entre 1 y 10: 5
#
# PC generó el número número: 5
# Felipe, ingresaste el número: 5
# {nombre} perdiste! 🙁

# %% [markdown]
# ## <font color='157699'> **Control del tipo de datos** </font>

# %% [markdown]
# Dependiendo del lenguaje de programación estos podran o no tener un control más o menos fuerte de los tipos de datos. Por ejemplo, Python es un lenguaje de *tipado débil* en el sentido que **no** debe especificarse el tipo de dato que almacenará la variable al momento de su creación, mientras que otros lenguajes si lo requieren. Veamos en términos prácticos a que se refiere esto:

# %%
diversa = 3
print("El valor de diversa es :", diversa, "es de tipo: ", type(diversa))
diversa = "Texto"
print("El valor de diversa es :", diversa, "es de tipo: ", type(diversa))
# Out:
# El valor de diversa es : 3 es de tipo:  <class 'int'>
# El valor de diversa es : Texto es de tipo:  <class 'str'>

# %% [markdown]
# Note que hemos usado la variable llamada `diversa` para almacenar dos tipos diferentes de datos.
#
# <font color='157699'> **TIP**: Dado que Python es un lenguaje débilmente tipado,  existe una función bastante útil que nos permite conocer el tipo de datos al que pertenece una variable. </font>
#
# ```python
# type(variable)
# ```

# %%
a = 3
print("El tipo de a es: ", type(a))
b = input("ingrese un número entre 0 y 9: ")
print("El tipo de b es: ", type(b))
# Out:
# El tipo de a es:  <class 'int'>
# ingrese un número entre 0 y 9: 1
# El tipo de b es:  <class 'str'>

# %% [markdown]
# Note que los datos entrados desde el teclado se leen de tipo String (`str`), es por esto que si ingresamos un número por teclado debemos hacer una operación llamada `cast` que convierte el tipo de datos al que se necesita, en este caso de *String* a un número entero *Integer*.
# Para más información sobre `casting`, se recomienda este [link](https://www.w3schools.com/python/python_casting.asp).
#
# Observe cómo en el siguiente ejemplo que la variable b cambia de tipo de dato a entero.

# %%
a = 3
print("El tipo de a es: ", type(a))
b = int(input("ingrese un número entre 0 y 9: "))
print("El tipo de b es: ", type(b))
# Out:
# El tipo de a es:  <class 'int'>
# ingrese un número entre 0 y 9: 5
# El tipo de b es:  <class 'int'>

# %% [markdown]
# #### <font color='46B8A9'> **Ejercicio 3** </font>
# Considera ahora el siguiente juego:
#
# > El computador genera un número aleatorio entre 1 y 10 y tú seras el **GANADOR** si consigues adivinarlo.
#
# En el siguiente programa está implementado el juego mencionado:

# %%
import random # importa random
aleatorio = random.randint(1, 5) # Genera un número aletaorio entre 1 y 10
escogido = int(input("Ingrese el número que tu consideres: ")) # Digitar el número solicitado

print(f'\nEl número generado fue {aleatorio}\n')

if aleatorio == escogido :
    print("Felicitaciones!!, has acertado!! 🙂")
else:
    print("No has acertado, intentalo nuevamente 🙁")
# Out:
# Ingrese el número que tu consideres: 2
#
# El número generado fue 3
#
# No has acertado, intentalo nuevamente 🙁

# %% [markdown]
# Es complicado, ¿cierto?. Te voy a ayudar un "poco" mostandote el número que ha generado el computador a ver si así puedes adivinarlo:

# %%
import random # importa random
aleatorio = random.randint(1, 10) # Genera un número aleatorio entre 1 y 10
print("El número aleatorio generado es: ", aleatorio) # Imprime el número generado

escogido = input("Ingrese el número ") # Digitar el número solicitado

if aleatorio == escogido :
    print("Felicitaciones!!, has acertado!! 🙂")
else:
    print("No has acertado, intentalo nuevamente 🙁")
# Out:
# El número aleatorio generado es:  3
# Ingrese el número 3
# No has acertado, intentalo nuevamente 🙁

# %% [markdown]
# * ¿Conseguiste adivinarlo?, ¿Cuál es la razón para que incluso sabiendo el número ganador, al ingresarlo el programa indica que no acertaste?

# %% [markdown]
# # <font color='056938'> **Operadores** </font>
#
# Los operadores realizan operaciones con variables y pueden clasificarse segun el tipo de operación que realizan y el tipo de variables que manipulan. En particular algunos de los tipos de operadores que distingue Python son:

# %% [markdown]
# ## <font color='157699'> **Operadores algebraicos** </font>
# | Operador| Operación 	| Descripción 	| Ejemplo (a=10 - b=20)|
# |:---|:---|:---|:---|
# | + | Suma 	| Suma los valores a ambos lados del operador 	| a + b = 30 	|
# | -  | Resta 	| Resta el valor de la derecha al valor que esta a la izquierda 	| a – b = -10 	|
# | *  | Multiplicación 	| Multiplica los valores a los dos lados del operador 	| a * b = 200 	|
# | / | División 	| Divide el valor de la izquierda sobre el de la derecha	| b / a = 2.0 	|
# | // | División entera	| Divide el valor de la izquierda sobre el de la derecha	| b // a = 2 	|
# | % | Módulo 	| Residuo de la división de dos números 	| b % a = 0 	|
# | ** | Exponente 	| Eleva a la potencia 	| a**b = $10^{20}$	|
#
# Observe los siguientes ejemplos

# %%
# Observe los siguientes ejemplos

# Dado los números enteros a y b:
a = 21
b = 10

c = a + b
print(f"{a} + {b} = {c}")

c = a - b
print(f"{a} - {b} = {c}")

c = a * b
print(f"{a} * {b} = {c}")

c = a / b
print(f"{a} / {b} = {c}")

c = a // b
print(f"{a} // {b} = {c}")

c = a % b
print(f"{a} % {b} = {c}")

a = 2
b = 3
c = a**b
print(f"{a} ** {b} = {c}")
# Out:
# 21 + 10 = 31
# 21 - 10 = 11
# 21 * 10 = 210
# 21 / 10 = 2.1
# 21 // 10 = 2
# 21 % 10 = 1
# 2 ** 3 = 8

# %% [markdown]
# ## <font color='157699'> *Jerarquia operadores algebraicos* </font>
# En programación, cuando se construye una expresión matemática o fórmula se debe tener en cuenta la jerarquía de operadores. La jerarquía de operadores determina el orden en el que se resuelven las expresiones cuando se involucran operaciones aritméticas como la suma, resta, multiplicación, división, potencia, raíz y módulo de la división.
#
# 1. Paréntesis.
# 2. Exponenciación, radicación y módulo.
# 3. División y multiplicación.
# 4. Suma y resto.
#
# * Si los operadores estan en el mismo nivel de jerarquia se realizan de izquierda a derecha
#
# * Si la operación contiene paréntesis, se realizan las operaciones que se encuentran en el paréntesis más interno, siguiendo el nivel de jerarquia mencionado anteriormente.

# %% [markdown]
# ### <font color='46B8A9'> **Ejercicio 4** </font>
# Empleando solo los operadores aritméticos presentados anteriormente, implementa la siguiente expresión aritmética y comprueba su resultado
#
# $$\left(\frac{11}{2}-4\right)^5*\left(\frac{\sqrt{5}+3^2-4*(\frac{5}{7}-\frac{4}{5})^2}{-7-\frac{3}{4}*(-3+4)^3}\right)=-4.8803$$

# %%
# Inserte su código aquí
((11/2-4)**3)*((5**0.5+3**2-4*(5/7-4/5)**2)/(-7-(3/4)*(-3+4)**3))
# Out:
# -4.880328483947406

# %% [markdown]
# Recuerde que la exponenciación también puede realizarse usando la función `pow()`, por ejemplo para calcular $\sqrt{5}$ se escribe
#
# ```python
# pow(5,0.5)
# ```
#
# pruebalo tu mismo

# %% [markdown]
# ### <font color='46B8A9'> **Ejercicio 5** </font>
#
# Los operadores *módulo de la división (%)* y *división entera (//)* no son empleados en las expresiones algebraicas a las que normalmente estamos acostumbrados en los cursos de ingeniería. Entonces, ¿cuales crees que serán los usos que se les dá en programación?, comparte con tus compañeros de clase tus opiniones.

# %% [markdown]
# ## <font color='157699'> **Operadores de comparación** </font>
#
# Comparan los valores a ambos lados del operador y deciden la relación entre dichos valores. Son también conocidos como operadores relacionales. El resultado de estas operaciones son almacenados en variables booleanas, es decir, aquellas variables que toman un valor verdadero (1 o True) o falso (0 o False).
#
#
# | Operador 	| Descripción 	| Sintaxis	| Ejemplo (a=10 y  b=20)|
# |----------	|-----------------------------------------------------------------------------------------------------------------------	|------------------------------------------------	|-------------|
# | == 	| Verdadero si los dos operandos son iguales 	| a == b| False |
# | != 	| Verdadero si los dos operandos son diferentes 	| a != b | True |
# | <> 	| Verdadero si los dos operandos son diferentes (usado en otros lenguajes de prog.)	| a <> b | True |
# | > 	| Verdadero si el operando de la izquierda es mayor que el de la derecha | a > b | False |
# | < 	| Verdadero si el operando de la izquierda es menor que el de la derecha 	| a < b | True |
# | >= 	| Verdadero si el operando de la izquierda es mayor o igual que el de la derecha | a >= b	| False |
# | <= 	| Verdadero si el operando de la izquierda es menor o igual que el de la derecha 	| a <= b	| True |

# %% [markdown]
# Por ejemplo, observe que valor toman las variables P y Q en las siguientes celdas:

# %%
P = 3 == 4 - 1
Q = 3 == 4
print(f'P toma el valor {P} y Q toma el valor {Q}')
# Out:
# P toma el valor True y Q toma el valor False

# %% [markdown]
# ### <font color='46B8A9'> **Ejercicio 6** </font>
# Para tres variables diferentes `a=10`, `b=7` y `c=3`, responda las siguientes preguntas escribiendo las instrucciones apropiadas y mostrando su resultado
#
#
# 1. ¿`a` es igual a `b + c`?
# 2. ¿`a` menos c es diferente a `b`?
# 3. ¿`b` es mayor que `a`?
# 4. ¿`c` es menor que `a`?
# 5. ¿`a*b` es mayor o igual `c`?
# 6. ¿2 veces `a` es mayor o igual que `b * c`?

# %%
#Escriba aqui su código

# %% [markdown]
# ## <font color='157699'> **Operadores lógicos** </font>
#
# Los operadores lógicos son elementos fundamentales en la lógica y la programación que permiten combinar o comparar expresiones lógicas para obtener un resultado basado en ciertas condiciones. Estos operadores se utilizan en diferentes contextos, como en programación, matemáticas, electrónica y sistemas de control.
#
# En la mayoría de los lenguajes de programación, los operadores lógicos trabajan con valores booleanos. Los operadores lógicos básicos son tres:
#
# | Operador 	| Descripción 	|
# |-----------------	|----------------------------------------------------------------------	|
# |  and 	| Verdadero si los dos operandos son verdaderos 	|
# |  or 	| Verdadero si uno de los operandos es verdadero 	|
# |  not 	| Reversa el estado lógico de un operando 	|
#
# Considere por ejemplo la siguiente expresión
#
# ```python
# (a > b) or not(b < c)
# ```
# En esta aparecen dos expresiones lógicas `(a > b)` y `not(b < c)` unidas por el operador lógico `or`. El resultado de la siguiente expresión dependerá entonces de los valores que tome cada una de las expresiones lógicas y que se puede resumir como
#
# | `(a>b)`	| `not(b<c)` | `(a > b) or not(b < c)`|
# |-----------------	|-----------------------------------	|--------|
# |  False 	| False	| False |
# |  True 	| False	| True |
# |  False 	| True | True |
# |  True 	| True | True |
#
# Considere por ejemplo que `a=10`, `b=20` y `c=15`. ¿Cúal esperas que sea el resultado de la anterior expresión?

# %% [markdown]
# ### <font color='46B8A9'> **Ejercicio 7** </font>
#
# Suponga que al iniciar un curso, el profesor junto con los estudiantes definieron que el curso se aprueba si se obtiene una nota tanto en el examen final como en los trabajos mayor o igual a la nota mínima de aprobación o por haber asistido al menos al 80% de las clases.
#
# Si se definen las siguientes variables
#
# * **notaExamen**: Representa la calificación obtenida en el examen final.
# * **notaTrabajos**: Representa la calificación promedio de los trabajos y tareas realizados durante el curso.
# * **asistencia**: Representa el porcentaje de asistencia a clases.
# * **notaMinimaAprobacion**: Representa la nota mínima requerida para aprobar la materia (notaMinimaAprobacion=3.0).
# * **apruebaCurso**: Representa la decisión final de aprobar o no el curso.
#
# Escriba la expresión lógica en *Python* cuyo resultado debe asignarse a la variable *apruebaCurso* y determine si los siguientes estudiantes aprueban o reprueban el curso:
#
# |Estudiante|notaExamen| notaTrabajos| asistencia |apruebaCurso|
# |----|----|----|----|----|
# |1 | 3.5 | 3.2 | 60 | ? |
# |2 | 2.5 | 1.2 | 80 | ? |
# |3 | 4.2 | 2.4 | 50 | ? |
# |4 | 3.7 | 1.9 | 90 | ? |
# |5 | 3.0 | 3.0 | 20 | ? |

# %%
#Ingrese aqui su código

# %% [markdown]
# ## <font color='157699'> **Operadores de asignación** </font>
#
# Son usados para asignar valores a las variables
#
# | Operador | Ejemplo | Equivalencia    |
# |----------|---------|------------|
# | =        | x = 5   | x = 5      |
# | +=       | x += 3  | x = x + 3  |
# | -=       | x -= 3  | x = x - 3  |
# | *=       | x *= 3  | x = x * 3  |
# | /=       | x /= 3  | x = x / 3  |
# | %=       | x %= 3  | x = x % 3  |
# | //=      | x //= 3 | x = x // 3 |
# | **=      | x **= 3 | x = x ** 3 |
# | &=       | x &= 3  | x = x & 3  |
# | \|=      | x \|= 3 | x = x \| 3 |

# %% [markdown]
# ### <font color='46B8A9'> **Ejercicio 8** </font>
#
# Experimente con algunos de dichos operadores. Por ejemplo, asumiendo que `a` inicialmente vale 5, use el operado `+=` para asignar en `a` el valor resultante de incrementar en 5 su valor inicial:

# %%
a = 10
a += 5
print(a)
# Out:
# 15

# %% [markdown]
# ## <font color='157699'> **Cuidado en el uso de los operadores** </font>
# Del tipo de dato almacenado en una variable dependerán las operaciones permitidas y el resultado obtenido. Note por ejemplo la diferencia de aplicar el operador producto `*` entre dos número o entre un número y una cadena de carácteres.

# %%
a = 5
b = 2
texto = "Pablo"

#Producto entre enteros
resultado = a * b
print("Producto entre enteros a y b :", resultado)

#Producto entre entero y string
resultado = texto * a
print("Producto entre entero y string, :", resultado)
# Out:
# Producto entre enteros a y b : 10
# Producto entre entero y string, : PabloPabloPabloPabloPablo

# %% [markdown]
# Más adelante se profundizará sobre el manejo de las cadenas de caracteres

# %% [markdown]
# # <font color='056938'> **Práctica** </font>

# %% [markdown]
# ### <font color='46B8A9'> **Ejercicio 9** </font>
# Considere un programa que dados dos números, el primero de ellos correspondiente al número total de kilos que deben empacarse en cajas (a = 207kg) y la capacidad en kilos de cada caja (b = 12 kilos).
#
# * Calcule el número de cajas necesarias para empacar toda la mercancia
# * Calcule la cantidad que quedaría sin empacar si solo pueden despacharse cajas completas
# * Determine el número de cajas necesarias para empacar toda la mercancia

# %%
# Librería de funciones matemáticas para números reales
import math
# Calcule aquí las cantidades solicitadas
a = 207
b = 12

cajas = 207/12
print("Número de cajas: ", cajas)

empacado = 17*12
sin_empacar = a - empacado
print("Cantidad empacada: ", empacado)
print("Cantidad sin empacadar: ", sin_empacar)
# Out:
# número de cajas:  17.25
# cantidad empacada:  204
# cantidad sin empacadar:  3

# %% [markdown]
# ### <font color='46B8A9'> **Ejercicio 10** </font>
#
# Paracaidista

# %%
import math

# Entradas:
m = float(input('Masa del paracaidista [kg]:    '))
C = float(input('Coeficiente de arrastre aerodinámico [Ns/m]:    '))
t = float(input('Tiempo de caída [s]:    '))

# Inicialización de variables
g = 9.81

# Procesos
V = ((m * g) / C) * (1 - math.exp(-(C/m) * t))

# Salidas:
print('\nLa velocidad del paracaidista a los %.2f [s] es %.2f [m/s]' % (t,V))
# Out:
# Masa del paracaidista [kg]:    70
# Coef. de arrastre aerodinámico [Ns/m]:    0.85
# Tiempo de caída [s]:    10
#
# La velocidad del paracaidista a los 10.00 [s] es 92.38 [m/s]

# %% [markdown]
# ### <font color='46B8A9'> **Ejercicio 11** </font>
#
# Desarrolle un programa que haga lo siguiente:
# * Solicite al usuario su nombre
# * Solicite al usuario su estatura
# * Solicite al usuario su peso
# * Calcule el <a href="https://rextester.com/l/vb">índice de masa corporal </a>
# * Genere un mensaje que le diga al usuario su índice
#     * (opcional) Si el índice esta en ente 18,5 y 24,9 genere un mensaje diciendo que está en una condición saludable óptima

# %%
# Escriba aquí su respuesta
nombre = input("¿Cuál es su nombre?: ")
estatura = float(input("¿Cuál es su estatura en cm?: "))/100
peso = float(input("¿Cuál es su peso en kg?: "))
imc = peso/(estatura**2)
print("Su índice de masa corporal es: ", imc)
# Out:
# ¿Cuál es su nombre?: Felipe
# ¿Cuál es su estatura en cm?: 172
# ¿Cuál es su peso en kg?: 63
# su indice de masa corporal es:  21.29529475392104
